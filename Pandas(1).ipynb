# %%
import pandas as pd
#1:from list
data=[10,20,30,40]
s=pd.Series(data)
print('Series from list:')
print(s)

#2.custom index
s2=pd.Series([100,200,300,400],index=['a','b','c','d'])
print("/nSeries with custom index:")
print(s2)

#3.from dictionary
data_dict={'riya':1,'surya':28,'rooba':24}
s3=pd.Series(data_dict)
print("/nSeries from dictionary:")
print(s3)
# Out:
# Series from list:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# /nSeries with custom index:
# a    100
# b    200
# c    300
# d    400
# dtype: int64
# /nSeries from dictionary:
# riya      1
# surya    28
# rooba    24
# dtype: int64

# %% [raw]
# #DataFrame(from dictionary)
# data={'Name':['Harsha','Prakash','Sabari'],'Marks':[100,98,96],'Subject':['Maths','Tamil','English']}
# df=pd.DataFrame(data)
# print('DataFrame from dictionary:')
# print(df)

# %%
print(['Name'])
# Out:
# ['Name']

# %%
#select one column
print(df['Name'])
# Out:
# 0     Harsha
# 1    Prakash
# 2     Sabari
# Name: Name, dtype: object

# %%
#select multiple column
print(df[['Name','Marks']])
# Out:
#       Name  Marks
# 0   Harsha    100
# 1  Prakash     98
# 2   Sabari     96

# %%
#filter rows
print(df[df['Marks']>96])
# Out:
#       Name  Marks Subject
# 0   Harsha    100   Maths
# 1  Prakash     98   Tamil

# %%
#add new column
df['City']=['Chennai','Pudukottai','Madurai']
print(df)
# Out:
#       Name  Marks  Subject        City
# 0   Harsha    100    Maths     Chennai
# 1  Prakash     98    Tamil  Pudukottai
# 2   Sabari     96  English     Madurai

# %%
import pandas as pd
data={'Employ':['Priya','Dharshini','Monisha','Jack','Vinoth'],
      'Department':['IT','HR','Finance','IT','Marketing'],
'Salary':[50000,49000,30000,45000,31000]}
df=pd.DataFrame(data)
print(df)
# Out:
#       Employ Department  Salary
# 0      Priya         IT   50000
# 1  Dharshini         HR   49000
# 2    Monisha    Finance   30000
# 3       Jack         IT   45000
# 4     Vinoth  Marketing   31000

# %%
print(df[df['Salary']>31000])
# Out:
#       Employ Department  Salary
# 0      Priya         IT   50000
# 1  Dharshini         HR   49000
# 3       Jack         IT   45000

# %%
#Sorting ascending/descending
#sort by salary ascending
print(df.sort_values('Salary'))
# Out:
#       Employ Department  Salary
# 2    Monisha    Finance   30000
# 4     Vinoth  Marketing   31000
# 3       Jack         IT   45000
# 1  Dharshini         HR   49000
# 0      Priya         IT   50000

# %%
#sort by salary descending
print(df.sort_values('Salary',ascending=False))
# Out:
#       Employ Department  Salary
# 0      Priya         IT   50000
# 1  Dharshini         HR   49000
# 3       Jack         IT   45000
# 4     Vinoth  Marketing   31000
# 2    Monisha    Finance   30000

# %%
#groupby
print(df.groupby('Department')['Salary'].mean())
# Out:
# Department
# Finance      30000.0
# HR           49000.0
# IT           47500.0
# Marketing    31000.0
# Name: Salary, dtype: float64

# %%
#Filtering
filtered=df[df['Salary']>40000]
print('Employees with Salary>40000:')
print(filtered)
# Out:
# Employees with Salary>40000:
#       Employ Department  Salary
# 0      Priya         IT   50000
# 1  Dharshini         HR   49000
# 3       Jack         IT   45000
